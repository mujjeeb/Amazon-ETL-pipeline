# %%
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine,MetaData, Table
import pandas as pd

# %%
# #Reading CSV file 
df = pd.read_csv('cleaned_amazon_review_data.csv')

# %%
df
# Out:
#                                           product_name  \
# 0    Montana West Genuine Leather Purses for Women ...
# 1    Montana West Genuine Leather Purses for Women ...
# 2    Montana West Genuine Leather Purses for Women ...
# 3    Montana West Genuine Leather Purses for Women ...
# 4    Montana West Genuine Leather Purses for Women ...
# ..                                                 ...
# 182  AO ALI VICTORY Glitter Clutch Purses for Women...
# 183  AO ALI VICTORY Glitter Clutch Purses for Women...
# 184  AO ALI VICTORY Glitter Clutch Purses for Women...
# 185  AO ALI VICTORY Glitter Clutch Purses for Women...
# 186  AO ALI VICTORY Glitter Clutch Purses for Women...
#
#                       category  price merchant_info  \
# 0    Clothing, Shoes & Jewelry  69.99    Amazon.com
# 1    Clothing, Shoes & Jewelry  69.99    Amazon.com
# 2    Clothing, Shoes & Jewelry  69.99    Amazon.com
# 3    Clothing, Shoes & Jewelry  69.99    Amazon.com
# ...

# %%
# Defining product_id column
df['productid'] = df.index
df.set_index('productid', inplace=True)

# %%
df
# Out:
#                                                 product_name  \
# productid
# 0          Montana West Genuine Leather Purses for Women ...
# 1          Montana West Genuine Leather Purses for Women ...
# 2          Montana West Genuine Leather Purses for Women ...
# 3          Montana West Genuine Leather Purses for Women ...
# 4          Montana West Genuine Leather Purses for Women ...
# ...                                                      ...
# 182        AO ALI VICTORY Glitter Clutch Purses for Women...
# 183        AO ALI VICTORY Glitter Clutch Purses for Women...
# 184        AO ALI VICTORY Glitter Clutch Purses for Women...
# 185        AO ALI VICTORY Glitter Clutch Purses for Women...
# 186        AO ALI VICTORY Glitter Clutch Purses for Women...
#
#                             category  price merchant_info  \
# productid
# 0          Clothing, Shoes & Jewelry  69.99    Amazon.com
# 1          Clothing, Shoes & Jewelry  69.99    Amazon.com
# ...

# %%
engine = create_engine('postgresql://postgres:mkhitaryan1@localhost:5432/amazon_products_db')
df.to_sql('amazon_products_table', engine, if_exists='append')
# Out:
# 187
